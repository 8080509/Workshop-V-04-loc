# %%
from data_src import sales, oil, date_index, pd, dates_dt_min
from data_pca import sales_pca, total_sales_pca

# %%
import matplotlib.pyplot as plt
import datetime as dt

# %%
plt.plot(sales_pca[:, 0, 1])

# %%
plt.plot(sales_pca[:, 1, :2])

# %%
plt.plot(total_sales_pca[:, 3])
plt.ylim((None, 40000))
# plt.plot(oil * 50)
# Out:
# (-12535.138268466155, 40000.0)

# %%
plt.plot(total_sales_pca[:, 2])
# plt.plot(oil * 100)
plt.ylim((None, 20000))
# Out:
# (-20771.495476856766, 20000.0)

# %%
date_index.loc[pd.to_datetime('2013-12-25')]
date_index.loc[pd.to_datetime('2014-12-25')]
date_index.loc[pd.to_datetime('2015-12-25')]
# Out:
# 0    1088
# Name: 2015-12-25 00:00:00, dtype: int64

# %%
dates_dt_min
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
dates_dt_min.day_of_week
# Out:
# 1

# %%
plt.plot(sales_pca[::7, 0, :2])

# %%
plt.plot(sales_pca[1::7, 0, :2])

# %%
plt.plot(sales_pca[2::7, 0, :2])

# %%
plt.plot(sales_pca[3::7, 0, :2])

# %%
plt.plot(sales_pca[4::7, 0, :2])
